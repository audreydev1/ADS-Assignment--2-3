# %% [markdown]
# # 1.0 Importing necessary Python Libraries

# %%
#importing the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1.1 Reading the Dataset from our CSV file

# %%
#creating a dataframe from the csv and naming it EmployeeAttrition
EmployeeAttrition=pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv")
EmployeeAttrition.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# # 1.2 Previewing our Dataset

# %%
#viewing the first 10 entries of our dataset
EmployeeAttrition.head(10)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
# 5   32        No  Travel_Frequently       1005  Research & Development
# 6   59        No      Travel_Rarely       1324  Research & Development
# 7   30        No      Travel_Rarely       1358  Research & Development
# 8   38        No  Travel_Frequently        216  Research & Development
# 9   36        No      Travel_Rarely       1299  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# ...

# %%
#viewing the last 10 entries of our dataset
EmployeeAttrition.tail(10)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1460   29        No      Travel_Rarely        468  Research & Development
# 1461   50       Yes      Travel_Rarely        410                   Sales
# 1462   39        No      Travel_Rarely        722                   Sales
# 1463   31        No         Non-Travel        325  Research & Development
# 1464   26        No      Travel_Rarely       1167                   Sales
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1460                28          4        Medical              1
# ...

# %%
#viewing the columns of our dataset
EmployeeAttrition.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# # 1.3 Understanding our Dataset

# %%
#Exploring our dataset
EmployeeAttrition.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
#Checking for the data types in our data
EmployeeAttrition.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
#checking how many rows and columns are there in our dataframe
EmployeeAttrition.shape
# Out:
# (1470, 35)

# %%
#finding the summary staistic for all the numeric columns in our dataset
EmployeeAttrition.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# # 1.4 Cleaning our Dataset

# %%
#Checking for any null values in our dataset
EmployeeAttrition[EmployeeAttrition.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Age, Attrition, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, EmployeeCount, EmployeeNumber, EnvironmentSatisfaction, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyIncome, MonthlyRate, NumCompaniesWorked, Over18, OverTime, PercentSalaryHike, PerformanceRating, RelationshipSatisfaction, StandardHours, StockOptionLevel, TotalWorkingYears, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager]
# Index: []
#
# [0 rows x 35 columns]

# %% [markdown]
# #### We do not have any null values in our dataset

# %%
#checking for duplicate rows in our dataset
EmployeeAttrition[EmployeeAttrition.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Age, Attrition, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, EmployeeCount, EmployeeNumber, EnvironmentSatisfaction, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyIncome, MonthlyRate, NumCompaniesWorked, Over18, OverTime, PercentSalaryHike, PerformanceRating, RelationshipSatisfaction, StandardHours, StockOptionLevel, TotalWorkingYears, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager]
# Index: []
#
# [0 rows x 35 columns]

# %% [markdown]
# #### Seems we do not have any duplicate rows in our dataset

# %% [markdown]
# # 1.3 Analysis

# %% [markdown]
# ## 1.3.1 Uncovering Factors that led to Employee Attrition

# %%
#Finding out how many employees attrited from the company
EmployeeAttrition["Attrition"].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
#subsetting our data set to only have employees who have attrited.
att_Yes=EmployeeAttrition[EmployeeAttrition["Attrition"]=="Yes"]
att_Yes.shape
# Out:
# (237, 35)

# %%
#plotting this data to get a clear view of how many employees attrited
plt.figure(figsize=(8,8))
sns.set_context("paper",font_scale=1.5)
ax=sns.countplot(x="Attrition",data=EmployeeAttrition)
for p in ax.patches:
    height = p.get_height()
    if np.isnan(height):
        height=0
    ax.text(p.get_x()+p.get_width()/2., height, '{:1.2f}'.format(height), ha="center")

plt.title("Employee Attrition")
plt.show()

# %% [markdown]
# ### From the analysis we can observe that 237 employees attrited out of the 1470 employees,which is about 16.12%

# %% [markdown]
# ## 1.3.1.1 Age with Respect to Attrition

# %%
#Analysing the Age Column
#Checking on how employee ages are distributed
plt.figure(figsize=(8,8))
sns.set_context("paper",font_scale=1.5)
sns.histplot(data=EmployeeAttrition, x="Age", hue="Attrition", multiple="stack",palette="magma",bins=np.arange(20,70,5))
plt.title("Hisogram for Employees Age Distribution by Attrition")
plt.show()

# %% [markdown]
# ### Most of the employees fall in the age bracket of between 30 years to 40 years,and we can also observe that attrition is high in the early ages as to compared to older ages.

# %%
# Checking for attrition across different ages
plt.figure(figsize=(26,20))
sns.set_context("paper",font_scale=2)
ax=sns.histplot(x="Age",hue="Attrition",data=att_Yes,palette="magma",bins=np.arange(20,70,5))
for p in ax.patches:
    height = p.get_height()
    if np.isnan(height):
        height=0
    ax.text(p.get_x()+p.get_width()/2., height, '{:1.2f}'.format(height), ha="center")
    
plt.ylabel("No. of employees that Attrited")    
plt.title("Histogram showing the Distribution of Attrited Employees")
plt.show()

# %% [markdown]
# ### From our visualization we can observe that employees in ages between 25 to 35  tend to attrite more

# %%
#Attrition by age and business travel
plt.figure(figsize=(16,10))
sns.set_context("paper",font_scale=1.5)
ax=sns.barplot(x="BusinessTravel",y="Age",hue="Attrition",data=EmployeeAttrition,palette="BuGn",ci=None)
for p in ax.patches:
    height = p.get_height()
    if np.isnan(height):
        height=0
    ax.text(p.get_x()+p.get_width()/2., height, '{:1.2f}'.format(height), ha="center")
    
plt.title("Employee Attrition with respect to Age and Business Travel")
plt.show()

# %% [markdown]
# ### We can observe that employees with an average age of between 32-34 tend to attrite regardless of whether they travel or not

# %% [markdown]
# ## 1.3.1.2 Attrition by Business Travel

# %%
#Checking for attrition by BusinessTravel
plt.figure(figsize=(26,20))
sns.set_style("dark")
sns.set_context("talk",font_scale=1.5)
ax=sns.countplot(x="BusinessTravel",hue="Attrition",data=EmployeeAttrition,palette="viridis")
for p in ax.patches:
    height = p.get_height()
    if np.isnan(height):
        height=0
    ax.text(p.get_x()+p.get_width()/2., height, '{:1.2f}'.format(height), ha="center")
    
plt.title("Employee Attrition with respect to Business Travel")
plt.show()

# %%
#pie chart to show the percentage of attrition in each department
plt.figure(figsize=(14,10))
att_Yes["BusinessTravel"].value_counts().plot.pie(autopct='%1.0f%%',startangle=90,
        shadow= True)
plt.title("Pie chart Showing the Attrition Percentage\n in regards to Business Travel")
plt.show()

# %% [markdown]
# ### From the analysis above we can observe that employees who rarely travel tend to attrite more.

# %% [markdown]
# # 1.3.1.3 Attrition by Department

# %%
#Checking for attrition by Department
plt.figure(figsize=(16,10))
sns.set_style("dark")
sns.set_context("paper",font_scale=1.5)
ax=sns.countplot(x="Department",hue="Attrition",data=EmployeeAttrition,palette="viridis")
for p in ax.patches:
    height = p.get_height()
    if np.isnan(height):
        height=0
    ax.text(p.get_x()+p.get_width()/2., height, '{:1.2f}'.format(height), ha="center")
    
plt.title("Employee Attrition by Department")
plt.show()

# %%
#pie chart to show the percentage of attrition in each department
plt.figure(figsize=(14,10))
att_Yes["Department"].value_counts().plot.pie(autopct='%1.0f%%',startangle=45,
        shadow= True)
plt.title("Pie chart Showing the Attrition Percentage by Department")
plt.show()

# %% [markdown]
# ### We can observe that Employees in the Research and Development department tend to attrite more

# %% [markdown]
# ## 1.3.1.4 Attrition with respect to Job Satisfaction

# %%
#Checking for attrition by Job Satisfaction
plt.figure(figsize=(26,20))
sns.set_style("dark")
sns.set_context("talk")
ax=sns.countplot(x="JobSatisfaction",hue="Attrition",data=EmployeeAttrition,palette="plasma")
for p in ax.patches:
    height = p.get_height()
    if np.isnan(height):
        height=0
    ax.text(p.get_x()+p.get_width()/2., height, '{:1.2f}'.format(height), ha="center")
    
plt.title("Employee Attrition with respect to Job Satisfaction")
plt.show()

# %%
#pie chart to show the percentage of attrition by job satisfaction
plt.figure(figsize=(14,10))
att_Yes["JobSatisfaction"].value_counts().plot.pie(autopct='%1.0f%%',startangle=45,
        shadow= True)
plt.title("Pie chart Showing the Attrition Percentage by Job Satisfaction")
plt.show()

# %% [markdown]
# ### Employees with a Job Satisfaction of 3 tend to attrite more

# %% [markdown]
# ## 1.3.5 Attrition with respect to Marital Status

# %%
plt.figure(figsize=(16,10))
sns.set_style("dark")
sns.set_context("paper",font_scale=1.5)
ax=sns.countplot(x="MaritalStatus",hue="Attrition",data=EmployeeAttrition,palette="YlGn")
for p in ax.patches:
    height = p.get_height()
    if np.isnan(height):
        height=0
    ax.text(p.get_x()+p.get_width()/2., height, '{:1.2f}'.format(height), ha="center")
    
plt.title("Employee Attrition by Marital Status")
plt.show()

# %%
#plotting a pie chart to represent the percentages
plt.figure(figsize=(14,10))
att_Yes["MaritalStatus"].value_counts().plot.pie(autopct='%1.0f%%',startangle=50,
        shadow= True,colors=['c','b','g'])
plt.title("Pie chart Showing Attrition by Marital Status")
plt.show()

# %% [markdown]
# ### Single Employees Tend to attrite more than married and divorced employees

# %% [markdown]
# ## 1.3.1.5 Attrition by Gender

# %%
plt.figure(figsize=(16,10))
sns.set_style("dark")
sns.set_context("paper",font_scale=1.5)
ax=sns.countplot(x="Gender",hue="Attrition",data=EmployeeAttrition,palette="summer")
for p in ax.patches:
    height = p.get_height()
    if np.isnan(height):
        height=0
    ax.text(p.get_x()+p.get_width()/2., height, '{:1.2f}'.format(height), ha="center")
    
plt.title("Employee Attrition by Gender")
plt.show()

# %%
#pie chart to represent gender by attrition
plt.figure(figsize=(14,10))
att_Yes["Gender"].value_counts().plot.pie(autopct='%1.0f%%',startangle=50,
        shadow= True,colors=['c','b','g'])
plt.title("Pie chart Showing Attrition by Gender")
plt.show()

# %% [markdown]
# ### Male Employees tend to attrite more than female employees

# %% [markdown]
# ## 1.3.1.6 Attrition with respect to Job Role

# %%
plt.figure(figsize=(16,10))
sns.set_style("dark")
sns.set_context("paper",font_scale=1.5)
ax=sns.countplot(x="JobRole",hue="Attrition",data=EmployeeAttrition,palette="summer")
for p in ax.patches:
    height = p.get_height()
    if np.isnan(height):
        height=0
    ax.text(p.get_x()+p.get_width()/2., height, '{:1.2f}'.format(height), ha="center")
    
plt.xticks(rotation=45)
plt.title("Employee Attrition by Job Role")
plt.show()

# %%
#pie chart to represent this information
plt.figure(figsize=(14,10))
att_Yes["JobRole"].value_counts().plot.pie(autopct='%1.0f%%',startangle=60,shadow= True,colors=['c','b','g','r','y','m'])
plt.title("Pie chart Showing Attrition by Job Role")
plt.show()

# %% [markdown]
#  ### We can observe that Laboratory Technicians and Sales Executives attrite more than employee with other Job roles

# %% [markdown]
# ## 1.3.1.7 Employee Attrition by WorkLife Balance

# %%
#plotting a countplot to check for attrition by work life balance
plt.figure(figsize=(16,10))
sns.set_style("dark")
sns.set_context("paper",font_scale=1.5)
ax=sns.countplot(x="WorkLifeBalance",hue="Attrition",data=EmployeeAttrition,palette="PuBuGn")
for p in ax.patches:
    height = p.get_height()
    if np.isnan(height):
        height=0
    ax.text(p.get_x()+p.get_width()/2., height, '{:1.2f}'.format(height), ha="center")
    
plt.title("Employee Attrition by Work Life Balance")
plt.show()

# %%
#plotting apie chart to represent attrition by work life balance
plt.figure(figsize=(14,10))
att_Yes["WorkLifeBalance"].value_counts().plot.pie(autopct='%1.0f%%',startangle=60,
        shadow= True,colors=['c','b','g','y'])
plt.title("Pie chart Showing Attrition by Work Life Balance")
plt.show()

# %% [markdown]
# #### From th above visualization we can observe that employees with  a work life balance of 3 tend to attrite more

# %% [markdown]
# ## 1.3.1.8 Employee Attrition With Respect to Education Field

# %%
#plotting a countplot for attrition by Education
plt.figure(figsize=(16,10))
sns.set_style("dark")
sns.set_context("paper",font_scale=1.5)
ax=sns.countplot(x="EducationField",hue="Attrition",data=EmployeeAttrition,palette="Greens")
for p in ax.patches:
    height = p.get_height()
    if np.isnan(height):
        height=0
    ax.text(p.get_x()+p.get_width()/2., height, '{:1.2f}'.format(height), ha="center")
    
plt.title("Employee Attrition by Education")
plt.show()

# %% [markdown]
# ### Life Sciences and Medical fields have the highest number of employees and attrition rate as well.

# %%
#pie chart to show attrition by education field
plt.figure(figsize=(14,10))
att_Yes["EducationField"].value_counts().plot.pie(autopct='%1.0f%%',startangle=60,
        shadow= True,colors=['c','b','g','y','m'])
plt.title("Pie chart Showing Attrition in Regards to Education Field")
plt.show()

# %% [markdown]
# # 1.4 Answering Research Questions

# %% [markdown]
# ## 1.4.1 Breakdown of distance from home by job role and attrition

# %%
#Summary Stastics for the distance from home column
EmployeeAttrition['DistanceFromHome'].describe()
# Out:
# count    1470.000000
# mean        9.192517
# std         8.106864
# min         1.000000
# 25%         2.000000
# 50%         7.000000
# 75%        14.000000
# max        29.000000
# Name: DistanceFromHome, dtype: float64

# %%
#Checking on how the distance from home is distributed
plt.figure(figsize=(16,10))
sns.set_context("paper",font_scale=1.5)
ax=sns.histplot(data=EmployeeAttrition, x="DistanceFromHome", hue="Attrition", multiple="stack",palette="magma",bins=np.arange(0,30,5))

plt.title("Hisogram for Attrition with respect to Distance From Home ")
plt.ylabel("Number of Employees")
plt.show()

# %% [markdown]
# ### We can observe that the distance from home for most employees is between 0-10 Miles

# %%
# Summary Statistics for the distance from home column from those who attrited
att_Yes['DistanceFromHome'].describe()
# Out:
# count    237.000000
# mean      10.632911
# std        8.452525
# min        1.000000
# 25%        3.000000
# 50%        9.000000
# 75%       17.000000
# max       29.000000
# Name: DistanceFromHome, dtype: float64

# %%
#Attrition with respect to Distance From Home and Job Role
EmployeeAttrition.groupby(['JobRole', 'Attrition']).agg({'DistanceFromHome':np.mean})
# Out:
#                                      DistanceFromHome
# JobRole                   Attrition
# Healthcare Representative No                 9.204918
#                           Yes               17.666667
# Human Resources           No                 6.600000
#                           Yes               13.416667
# Laboratory Technician     No                 9.329949
#                           Yes                9.661290
# Manager                   No                 7.927835
#                           Yes               10.000000
# Manufacturing Director    No                 9.533333
#                           Yes                8.800000
# Research Director         No                 8.474359
#                           Yes                7.000000
# Research Scientist        No                 8.869388
#                           Yes                9.765957
# Sales Executive           No                 9.026022
#                           Yes               12.649123
# ...

# %%
#plotting the data
plt.figure(figsize=(16,10))
sns.set_context("paper",font_scale=1.5)
ax=sns.barplot(x="JobRole",y="DistanceFromHome",hue="Attrition",data=EmployeeAttrition,palette="viridis",ci=None)
for p in ax.patches:
    height = p.get_height()
    if np.isnan(height):
        height=0
    ax.text(p.get_x()+p.get_width()/2., height, '{:1.2f}'.format(height), ha="center")
plt.xticks(rotation=45)    
plt.title("Employee Attrition by Job Role and Distance From Home")
plt.show()

# %% [markdown]
# ###  We can observe that employees who stay more than 9 kilometers from the office are more likely to attrite regardless of the job role

# %% [markdown]
# ## 1.4.2 Comparing Average Monthly Income By Education and Attrition

# %%
#Summary Statistics For the monthly income Statistics
EmployeeAttrition["MonthlyIncome"].describe()
# Out:
# count     1470.000000
# mean      6502.931293
# std       4707.956783
# min       1009.000000
# 25%       2911.000000
# 50%       4919.000000
# 75%       8379.000000
# max      19999.000000
# Name: MonthlyIncome, dtype: float64

# %%
#checking the distribution of monthly income
plt.figure(figsize=(8,8))
sns.set_context("paper",font_scale=1.5)
ax=sns.histplot(data=EmployeeAttrition, x="MonthlyIncome", hue="Attrition", multiple="stack",palette="magma")
plt.title("Histogram for Monthly Income")
plt.show()

# %%
#analysing the education column
EmployeeAttrition["Education"].value_counts()
# Out:
# 3    572
# 4    398
# 2    282
# 1    170
# 5     48
# Name: Education, dtype: int64

# %%
#checking how Education and job role are distributed
pd.crosstab(EmployeeAttrition['Education'], EmployeeAttrition['JobRole'], normalize = 'index')
# Out:
# JobRole    Healthcare Representative  Human Resources  Laboratory Technician  \
# Education
# 1                           0.088235         0.029412               0.205882
# 2                           0.074468         0.042553               0.202128
# 3                           0.083916         0.038462               0.181818
# 4                           0.110553         0.025126               0.145729
# 5                           0.062500         0.062500               0.104167
#
# JobRole     Manager  Manufacturing Director  Research Director  \
# Education
# 1          0.052941                0.088235           0.041176
# 2          0.067376                0.117021           0.046099
# 3          0.069930                0.094406           0.052448
# 4          0.072864                0.095477           0.057789
# 5          0.104167                0.104167           0.145833
#
# JobRole    Research Scientist  Sales Executive  Sales Representative
# Education
# ...

# %%
#plotting the data for employee attrition by Education
plt.figure(figsize=(16,10))
sns.set_style("dark")
sns.set_context("paper",font_scale=1.5)
ax=sns.countplot(x="Education",hue="Attrition",data=EmployeeAttrition,palette="summer")
for p in ax.patches:
    height = p.get_height()
    if np.isnan(height):
        height=0
    ax.text(p.get_x()+p.get_width()/2., height, '{:1.2f}'.format(height), ha="center")
    
plt.title("Employee Attrition by Education")
plt.show()

# %% [markdown]
# ### Employees with education level 3 are the majority in the organization and they tend to attrite more.

# %%
#compairing average monthly income by education and attrition
EmployeeAttrition.groupby(['Education', 'Attrition']).agg({'MonthlyIncome':np.mean})
# Out:
#                      MonthlyIncome
# Education Attrition
# 1         No           5926.129496
#           Yes          4360.161290
# 2         No           6586.058824
#           Yes          4282.545455
# 3         No           6882.919662
#           Yes          4770.242424
# 4         No           7087.814706
#           Yes          5335.155172
# 5         No           8559.906977
#           Yes          5850.200000

# %%
#plotting the data
plt.figure(figsize=(16,10))
sns.set_context("paper",font_scale=1.5)
ax=sns.barplot(x="Education",y="MonthlyIncome",hue="Attrition",data=EmployeeAttrition,palette="viridis",ci=None)
for p in ax.patches:
    height = p.get_height()
    if np.isnan(height):
        height=0
    ax.text(p.get_x()+p.get_width()/2., height, '{:1.2f}'.format(height), ha="center")   
plt.title("Average Monthly Income by Attrition and Education")
plt.show()

# %% [markdown]
# ### We can observe that the average monthly income increases with the education level i.e. the higher the level of education the higher the income.
# ### Average monthly income for those who attrited is less than those who have not attrited across all the education levels.
